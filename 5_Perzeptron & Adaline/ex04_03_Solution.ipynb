# %% [markdown]
# # Perzeptron
# ## Lernalgorithmus

# %%
import csv
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plot
import numpy as np

matplotlib.rcParams['figure.figsize'] = (7, 4)

# %%
def load_data(filename):
    """
    load a 2-d dataset with labels from a csv file in the format y,x1,x2
    and outputs three numpy arrays for the x1, x2, and y values where the labels
    have been converted to {0.0, 1.0}
    """
    with open(filename, 'r') as csvfile:
        pointreader = csv.reader(csvfile, delimiter=',')
        x1 = []
        x2 = []
        y = []
        for row in pointreader:
            x1.append(float(row[1]))
            x2.append(float(row[2]))
            y.append(0.0 if float(row[0]) == -1.0 else 1.0)
    return np.array(x1), np.array(x2), np.array(y)

# load linearly seperable dataset https://github.com/cuekoo/Binary-classification-dataset
x1, x2, y = load_data('data/linsep.csv')

# shuffle data to prevent unwanted effects during learning
s = np.arange(x1.shape[0])
#np.random.shuffle(s)
x1 = x1[s]
x2 = x2[s]
y = y[s]

# %% [markdown]
# # Überblick

# %%
plot.scatter(x1, x2, c=y, cmap=matplotlib.colors.ListedColormap(['red', 'blue']))

# %% [markdown]
# # Aufgabe 3.2
# Der Datensatz ist linear trennbar.

# %% [markdown]
# # Implementierung

# %%
def perceptron_classify(x1, x2, w):
    """
    classify a 2-d data point [x1,x2]^T via the weights w=[w0,w1,w2]^T
    """
    t = w[0] + x1 * w[1] + x2 * w[2]
    #return 1 if t > 0.0 else 0
    return 1.0 if t > 0.0 else 0.0
    
def perceptron_visualize(x1, x2, y, w):
    """
    scatter plot the data points and add a plot of the decision surface
    """
    plot.figure()
    plot.scatter(x1, x2, c=y, cmap=matplotlib.colors.ListedColormap(['red', 'blue']))
    plot.plot([x1.min(), x1.max()], [-(w[0] + w[1] * x1.min()) / w[2] , -(w[0] + w[1] * x1.max()) / w[2]])
    
def perceptron_learn_step(x1, x2, y, w):
    """
    perform a full perceptron learning step over all data points [x1_i,x2_i]^T 
    with labels y_i, update the weights w accordingly and return the new weights
    """
    wp = w[:]
    for x1_i, x2_i, y_i in zip(x1, x2, y):
        prediction = perceptron_classify(x1_i, x2_i, w)
        
        correction = y_i - prediction
        
        wp[0] = wp[0] + correction * 1.0
        wp[1] = wp[1] + correction * x1_i
        wp[2] = wp[2] + correction * x2_i
        
    return wp

def perceptron_accuracy(x1, x2, y, w):
    """
    compute the accuracy when applying the perceptron with weights w to all 
    data points [x1_i,x2_i]^T with labels y_i
    """ 
    correct = 0.0
    for x1_i, x2_i, y in zip(x1, x2, y):
        if perceptron_classify(x1_i, x2_i, w) == y:
            correct = correct + 1.0
    return correct / len(x1)

def perceptron_learn(x1, x2, y, gamma):
    """
    implementation of the perceptron learning algorithm on data points 
    [x1_i,x2_i]^T with labels y_i with accuracy threshold gamma and visualization
    every 10 iterations
    """
    rho = 0
    w = [0.0, 0.0, 0.0]
    iteration = 0
    while (rho < gamma):
        w = perceptron_learn_step(x1, x2, y, w)
        rho = perceptron_accuracy(x1, x2, y, w)
        print("iteration=", iteration, "accuracy =", rho)
        if iteration % 10 == 0:
            perceptron_visualize(x1, x2, y, w)
        iteration += 1
    return w

# %% [markdown]
# # Training

# %%
w = perceptron_learn(x1, x2, y, 1.0)
# Out:
# iteration= 0 accuracy = 0.5
# iteration= 1 accuracy = 0.75
# iteration= 2 accuracy = 0.5
# iteration= 3 accuracy = 0.5
# iteration= 97 accuracy = 0.99
# iteration= 98 accuracy = 0.99
# iteration= 99 accuracy = 0.98
# iteration= 100 accuracy = 0.99
# iteration= 101 accuracy = 0.99
# iteration= 102 accuracy = 0.99
# iteration= 103 accuracy = 0.99
# iteration= 104 accuracy = 0.99
# iteration= 105 accuracy = 0.99
# iteration= 106 accuracy = 0.98
# iteration= 107 accuracy = 0.99
# iteration= 108 accuracy = 0.99
# iteration= 109 accuracy = 0.99
# iteration= 110 accuracy = 0.99
# iteration= 111 accuracy = 0.99
# iteration= 112 accuracy = 0.99
# iteration= 113 accuracy = 0.99
# iteration= 114 accuracy = 0.98
# iteration= 115 accuracy = 0.99
# iteration= 116 accuracy = 0.99
# iteration= 117 accuracy = 0.99
# iteration= 118 accuracy = 0.99
# iteration= 119 accuracy = 0.99
# iteration= 120 accuracy = 0.99
# iteration= 121 accuracy = 0.98
# iteration= 122 accuracy = 0.99
# iteration= 123 accuracy = 0.99
# iteration= 124 accuracy = 0.99
# iteration= 125 accuracy = 0.99
# iteration= 126 accuracy = 0.99
# iteration= 127 accuracy = 0.99
# iteration= 128 accuracy = 0.99
# iteration= 129 accuracy = 0.98
# iteration= 130 accuracy = 0.99
# iteration= 131 accuracy = 0.99
# iteration= 132 accuracy = 0.99
# iteration= 133 accuracy = 0.99
# iteration= 134 accuracy = 0.99
# iteration= 135 accuracy = 0.99
# iteration= 136 accuracy = 0.98
# iteration= 137 accuracy = 0.99
# iteration= 138 accuracy = 0.99
# iteration= 139 accuracy = 0.99
# iteration= 140 accuracy = 0.99
# iteration= 141 accuracy = 0.99
# iteration= 142 accuracy = 0.99
# iteration= 143 accuracy = 0.99
# iteration= 144 accuracy = 0.98
# iteration= 145 accuracy = 0.99
# iteration= 146 accuracy = 0.99
# iteration= 147 accuracy = 0.99
# iteration= 148 accuracy = 0.99
# iteration= 149 accuracy = 0.99
# iteration= 150 accuracy = 0.99
# iteration= 151 accuracy = 0.98
# iteration= 152 accuracy = 0.99
# iteration= 153 accuracy = 0.99
# iteration= 154 accuracy = 0.99
# iteration= 155 accuracy = 0.99
# iteration= 156 accuracy = 0.99
# iteration= 157 accuracy = 0.99
# iteration= 158 accuracy = 0.99
# iteration= 159 accuracy = 0.98
# iteration= 160 accuracy = 0.99
# iteration= 161 accuracy = 0.99
# iteration= 162 accuracy = 0.99
# iteration= 163 accuracy = 0.99
# iteration= 164 accuracy = 0.99
# iteration= 165 accuracy = 0.99
# iteration= 166 accuracy = 0.98
# iteration= 167 accuracy = 0.99
# iteration= 168 accuracy = 0.99
# iteration= 169 accuracy = 0.99
# iteration= 170 accuracy = 0.99
# iteration= 171 accuracy = 0.99
# iteration= 172 accuracy = 0.99
# iteration= 173 accuracy = 0.99
# iteration= 174 accuracy = 0.98
# iteration= 175 accuracy = 0.99
# iteration= 176 accuracy = 0.99
# iteration= 177 accuracy = 0.99
# iteration= 178 accuracy = 0.99
# iteration= 179 accuracy = 0.99
# iteration= 180 accuracy = 1.0

# %%
w
# Out:
# [175.0, -417.18390000000375, 347.69630000000143]

# %% [markdown]
# - Es wurden 180 Iterationen benötigt, um eine 100%-ige Genauigkeit zu erreichen
# .- Die finalen Gewichte sind $\mathbf{w}_0=175$, $\mathbf{w}_1=-417.174$ und $\mathbf{w}_2=347.6963$
